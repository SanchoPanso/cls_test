# %%
import requests
import json

# %%
js_path = '/home/timssh/ML/TAGGING/test/tits_size/1/couple-fucking-porn-802/ret_meta.json'

def get_meta(picset):
    with open(picset, 'r', encoding="utf-8") as js_f:
        my_js = json.load(js_f)
    return my_js

data = get_meta(js_path)

# %% [markdown]
# ## Login

# %%
# headers = {'Authorization': 'bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjMzOTY0MzIwNDEsIklkZW50aXR5Ijp7IkdVSUQiOiJmOTdjM2NlOS1jNzgxLTRmYmUtYjMzMy0zOTBhNzk5ZjMyOTQiLCJMb2dpbiI6ImFkbWluIiwiUm9sZXMiOltdfX0.x_USiqCD0KtC_kcskv1zN4SNaMtc9qlHkErOShOa2FA'}
headers = {
    'Content-Type': 'application/json'
    }
data_log = {
  "login": "admin",
  "password": "nC82JpRPLx61901c"
}

url = "https://yapics.dev.collect.monster/v1/login"

r = requests.post(url, data=json.dumps(data_log), headers=headers)
token = eval(r.text)['token']
token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..LIgtSc_NrWHvaEsoBUVQMPvFMokTSsrFsPSqPOEVE_w'

# %% [markdown]
# ## GET Groups

# %%
url = 'https://yapics.dev.collect.monster/v1/series'
head = {"Authorization":f"token {token}", 'Content-Type': 'application/json'}
r1 = requests.get(url, headers=head)
# r1 = requests.get(url, data=json.dumps(data_log))
r1, r1.text
# Out:
# (<Response [200]>,
# ...

# %% [markdown]
# ## POST Meta_ret

# %%
url = 'https://yapics.dev.collect.monster/v1/picset/trained'
head = {"Authorization":f"token {token}"}
r1 = requests.post(url, data=json.dumps(data), headers=head, timeout=500000)
r1, r1.text
# Out:
# (<Response [500]>,
#  '{"error":[{"message":"unable get picsets: 970205e8-54b1-450c-9a14-16475c646802: record not found"}]}')

# %%
for item in data['items']:
    item['trained'].append({
            "group": "group_of_girls",
            "category": ['one girl']
        })
url = 'https://yapics.collect.monster/v1/picset/trained'
head = {"Authorization":f"token {token}"}
r1 = requests.post(url, data=json.dumps(data), headers=head, timeout=500000)
print(r1, r1.text)
# Out:
# <Response [200]> {}

# %% [markdown]
# # Get picsets full meta

# %%
import requests
import json


url = 'https://yapics.dev.collect.monster/v1/meta/picsets'
bearer = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..LIgtSc_NrWHvaEsoBUVQMPvFMokTSsrFsPSqPOEVE_w'

head = {"Authorization":f"bearer {bearer}", 'Content-Type': 'application/json'}

guids = {
  "guids": [
    # "7aef582d-b916-4283-acf8-4e95b4f9a65a",
    # "188e3326-32af-4a91-9176-f0987130d866",
    # "4f837bde-d89c-4987-8ac0-feacda5ba1c7"
    "3a5d0567-97f1-4ed7-9450-40228207875e"
  ]
}

r1 = requests.post(url, data=json.dumps(guids), headers=head, timeout=500000)
r1, r1.text
# Out:
# (<Response [500]>, '{"error":[{"message":"record not found"}]}')

# %% [markdown]
# # Get pictures by groups(0) OR category(1)

# %%
url = 'https://yapics.dev.collect.monster/v1/meta/pictures'
bearer = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..4MRzYFQZ-oJ9hmbjuutgdxUFO4kHoEJJxsTRBG5MG94'
head = {"Authorization":f"bearer {bearer}", 'Content-Type': 'application/json'}

groups = {
  "listBy": 0,
  "categories": [],
  "groups": ["boobs"]
}

r1 = requests.post(url, data=json.dumps(groups), headers=head, timeout=500000)
r1, r1.text
# Out:
# (<Response [401]>,
#  '{"error":[{"message":"access token is invalid: failed parse jwt token string: token is expired by 26h51m42s: internal error"}]}')

# %%
# !curl -XPOST -H'Authorization: bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..kqXcNAepyIeIisG8vqhYDHs8gNjIAaq--tKAPM2gass' -H 'Content-Type: application/json' -d '{ \
  "guids": ["4f837bde-d89c-4987-8ac0-feacda5ba1c7"] \
}'  https://yapics.collect.monster/v1/meta/picsets
# Out:
# {"data":[{"picset":{"guid":"4f837bde-d89c-4987-8ac0-feacda5ba1c7", "query":"brazzers pornstar sex porn", "quantity":"1500", "imageSize":"", "orientation":"horizontal", "imageType":"photo", "fileType":"jpg", "imageWidth":"0", "imageHeight":"0", "tags":[], "origin":"Body", "group":[{"group":"body_type", "category":["normal body", "fat", "skinny", "body_type trash", "athletic", "curvy", "bodybuilder"]}], "category":["normal body"]}, "items":[{"id":"5c32e5b28a5d747aeace55d506ef30a0", "title":"▷ Mackenzee Pierce В Taste My Sweet Tits (Фото 12) Brazzers", "text":"Mackenzee Pierce В &apos;Вкус мои сладкие сиськи&apos; from &apos;<b>Brazzers</b>&...", "origin":{"guid":"d14440f2-c743-4ec4-b8b1-072320cf01a8", "picsetGuid":"4f837bde-d89c-4987-8ac0-feacda5ba1c7", "url":"https://avatars.mds.yandex.net/i?id=1bdbeee35c558dd0eca0b4fff204d3f1-3493287-images-thumbs&n=13", "width":"2400", "height":"1599", "filepath":"4/f/8/4f837bde-d89c-4987-8ac0-feacda5ba1c7/p/5c32e5b28a5d747aeace55d506ef30a0.jpeg", "
# ...
