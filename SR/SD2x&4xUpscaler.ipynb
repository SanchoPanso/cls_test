# %%
# !pip install diffusers
# !pip install transformers
# !pip install scipy
# !pip install ftfy
# !pip install accelerate
# !pip install modin[all]
# !pip install gradio
# Out:
# Collecting diffusers
#   Downloading diffusers-0.17.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.4 MB/s eta 0:00:00a 0:00:010m
# Requirement already satisfied: numpy in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from diffusers) (1.24.3)
# Requirement already satisfied: importlib-metadata in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from diffusers) (6.6.0)
# Requirement already satisfied: requests in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from diffusers) (2.29.0)
# Requirement already satisfied: filelock in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from diffusers) (3.9.0)
# Collecting regex!=2019.12.17
#   Downloading regex-2023.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.4/770.4 kB 6.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: huggingface-hub>=0.13.2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from diffusers) (0.14.1)
# Requirement already satisfied: Pillow in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from diffusers) (9.4.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers) (4.5.0)
# Requirement already satisfied: fsspec in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers) (2023.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers) (6.0)
# Requirement already satisfied: packaging>=20.9 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers) (20.9)
# Requirement already satisfied: zipp>=0.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from importlib-metadata->diffusers) (3.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->diffusers) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->diffusers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->diffusers) (2022.12.7)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.13.2->diffusers) (2.4.7)
# Installing collected packages: regex, diffusers
# Successfully installed diffusers-0.17.1 regex-2023.6.3
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 6.7 MB/s eta 0:00:0000:0100:010m
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: filelock in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from transformers) (0.14.1)
# Requirement already satisfied: requests in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from transformers) (2.29.0)
# Requirement already satisfied: packaging>=20.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from transformers) (20.9)
# Requirement already satisfied: numpy>=1.17 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: tqdm>=4.27 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from transformers) (4.65.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 23.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyyaml>=5.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: fsspec in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->transformers) (2.0.4)
# Installing collected packages: tokenizers, safetensors, transformers
# Successfully installed safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2
# Requirement already satisfied: scipy in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from scipy) (1.24.3)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 257.2 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: wcwidth>=0.2.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ftfy) (0.2.6)
# Installing collected packages: ftfy
# Successfully installed ftfy-6.1.1
# Collecting accelerate
#   Downloading accelerate-0.20.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 603.4 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: torch>=1.6.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: psutil in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from accelerate) (5.9.1)
# Requirement already satisfied: packaging>=20.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from accelerate) (20.9)
# Requirement already satisfied: pyyaml in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from accelerate) (6.0)
# Requirement already satisfied: numpy>=1.17 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from accelerate) (1.24.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (2.4.7)
# Requirement already satisfied: typing-extensions in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (2.0.0)
# Requirement already satisfied: sympy in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (1.11.1)
# Requirement already satisfied: filelock in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (3.9.0)
# Requirement already satisfied: jinja2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (3.1.2)
# Requirement already satisfied: networkx in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (2.8.4)
# Requirement already satisfied: cmake in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (3.26.3)
# Requirement already satisfied: lit in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (16.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->accelerate) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch>=1.6.0->accelerate) (1.2.1)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.20.3
# Collecting modin[all]
#   Downloading modin-0.22.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.6 MB/s eta 0:00:00a 0:00:010m
# Requirement already satisfied: numpy>=1.18.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from modin[all]) (1.24.3)
# Requirement already satisfied: pandas==1.5.3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from modin[all]) (1.5.3)
# Requirement already satisfied: packaging in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from modin[all]) (20.9)
# Requirement already satisfied: fsspec in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from modin[all]) (2023.4.0)
# Requirement already satisfied: psutil in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from modin[all]) (5.9.1)
# Collecting distributed>=2.22.0
#   Downloading distributed-2023.6.1-py3-none-any.whl (980 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 980.4/980.4 kB 6.2 MB/s eta 0:00:0000:0100:01
# Collecting rpyc==4.1.5
#   Downloading rpyc-4.1.5-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 3.7 MB/s eta 0:00:00
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting boto3
#   Downloading boto3-1.27.0-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.9/135.9 kB 6.9 MB/s eta 0:00:00
# Collecting ray[default]>=1.13.0
#   Downloading ray-2.5.1-cp310-cp310-manylinux2014_x86_64.whl (56.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 MB 11.7 MB/s eta 0:00:0000:0100:01
# Collecting unidist[mpi]>=0.2.1
#   Downloading unidist-0.3.0-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 kB 6.0 MB/s eta 0:00:00
# Collecting dask>=2.22.0
#   Downloading dask-2023.6.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.0 MB/s eta 0:00:0000:01
# Collecting modin-spreadsheet>=0.1.0
#   Downloading modin_spreadsheet-0.1.2-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 6.2 MB/s eta 0:00:0000:01:00:01
# Collecting pyarrow
#   Downloading pyarrow-12.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 19.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from pandas==1.5.3->modin[all]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from pandas==1.5.3->modin[all]) (2023.3)
# Collecting plumbum
#   Downloading plumbum-1.8.2-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from dask>=2.22.0->modin[all]) (8.1.3)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from dask>=2.22.0->modin[all]) (6.6.0)
# Collecting partd>=1.2.0
#   Downloading partd-1.4.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from dask>=2.22.0->modin[all]) (6.0)
# Requirement already satisfied: toolz>=0.10.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from dask>=2.22.0->modin[all]) (0.12.0)
# Requirement already satisfied: msgpack>=1.0.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from distributed>=2.22.0->modin[all]) (1.0.3)
# Collecting sortedcontainers>=2.0.5
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting zict>=2.2.0
#   Downloading zict-3.0.0-py2.py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.0 MB/s eta 0:00:00
# Collecting tblib>=1.6.0
#   Downloading tblib-2.0.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: urllib3>=1.24.3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from distributed>=2.22.0->modin[all]) (1.26.15)
# Requirement already satisfied: tornado>=6.0.4 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from distributed>=2.22.0->modin[all]) (6.1)
# Requirement already satisfied: jinja2>=2.10.3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from distributed>=2.22.0->modin[all]) (3.1.2)
# Collecting locket>=1.0.0
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting jupyter>=1.0.0
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting notebook>=6.0.3
#   Downloading notebook-6.5.4-py3-none-any.whl (529 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.8/529.8 kB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from modin-spreadsheet>=0.1.0->modin[all]) (8.0.6)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from packaging->modin[all]) (2.4.7)
# Requirement already satisfied: jsonschema in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ray[default]>=1.13.0->modin[all]) (4.17.3)
# Collecting grpcio<=1.51.3,>=1.42.0
#   Downloading grpcio-1.51.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 24.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ray[default]>=1.13.0->modin[all]) (3.9.0)
# Requirement already satisfied: frozenlist in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ray[default]>=1.13.0->modin[all]) (1.3.3)
# Requirement already satisfied: attrs in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ray[default]>=1.13.0->modin[all]) (23.1.0)
# Requirement already satisfied: requests in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ray[default]>=1.13.0->modin[all]) (2.29.0)
# Requirement already satisfied: aiosignal in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ray[default]>=1.13.0->modin[all]) (1.3.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ray[default]>=1.13.0->modin[all]) (4.22.4)
# Requirement already satisfied: aiohttp>=3.7 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ray[default]>=1.13.0->modin[all]) (3.8.4)
# Requirement already satisfied: pydantic in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ray[default]>=1.13.0->modin[all]) (1.9.1)
# Collecting prometheus-client>=0.7.1
#   Downloading prometheus_client-0.17.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.1 MB/s eta 0:00:00
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 42.2 MB/s eta 0:00:0000:0100:01
# Collecting colorful
#   Downloading colorful-0.5.5-py2.py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 10.6 MB/s eta 0:00:00
# Collecting virtualenv<20.21.1,>=20.0.24
#   Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 24.1 MB/s eta 0:00:0000:0100:01
# Collecting gpustat>=1.0.0
#   Downloading gpustat-1.1.tar.gz (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 5.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting smart-open
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 2.6 MB/s eta 0:00:00
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting opencensus
#   Downloading opencensus-0.11.2-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 6.4 MB/s eta 0:00:00
# Collecting mpi4py-mpich
#   Downloading mpi4py_mpich-3.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 8.6 MB/s eta 0:00:0000:01m00:01
# Collecting botocore<1.31.0,>=1.30.0
#   Downloading botocore-1.30.0-py3-none-any.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 21.7 MB/s eta 0:00:0000:0100:01
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 4.4 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]>=1.13.0->modin[all]) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]>=1.13.0->modin[all]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]>=1.13.0->modin[all]) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]>=1.13.0->modin[all]) (4.0.2)
# Collecting nvidia-ml-py>=11.450.129
#   Downloading nvidia_ml_py-11.525.131-py3-none-any.whl (35 kB)
# Requirement already satisfied: blessed>=1.17.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[default]>=1.13.0->modin[all]) (1.19.1)
# Requirement already satisfied: zipp>=0.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask>=2.22.0->modin[all]) (3.15.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.15.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (8.13.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from jinja2>=2.10.3->distributed>=2.22.0->modin[all]) (2.1.1)
# Collecting nbconvert
#   Downloading nbconvert-7.6.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 14.9 MB/s eta 0:00:00
# Collecting qtconsole
#   Downloading qtconsole-5.4.3-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 6.8 MB/s eta 0:00:00
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: jupyter-core>=4.6.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (7.3.4)
# Collecting nbclassic>=0.4.7
#   Downloading nbclassic-1.0.0-py3-none-any.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 21.6 MB/s eta 0:00:0000:010:01
# Collecting terminado>=0.8.3
#   Downloading terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: nbformat in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (5.8.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.5.6)
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: pyzmq>=17 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (25.0.2)
# Requirement already satisfied: six>=1.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas==1.5.3->modin[all]) (1.16.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default]>=1.13.0->modin[all]) (0.3.6)
# Requirement already satisfied: platformdirs<4,>=2.4 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default]>=1.13.0->modin[all]) (3.5.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from jsonschema->ray[default]>=1.13.0->modin[all]) (0.19.3)
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.11.1-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.5/120.5 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from pydantic->ray[default]>=1.13.0->modin[all]) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->ray[default]>=1.13.0->modin[all]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->ray[default]>=1.13.0->modin[all]) (2022.12.7)
# Requirement already satisfied: wcwidth>=0.1.4 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]>=1.13.0->modin[all]) (0.2.6)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2
#   Downloading googleapis_common_protos-1.59.1-py2.py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 12.0 MB/s eta 0:00:00
# Collecting google-auth<3.0.dev0,>=2.14.1
#   Downloading google_auth-2.21.0-py2.py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.1/182.1 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: debugpy>=1.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.38)
# Requirement already satisfied: pickleshare in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.18.2)
# Requirement already satisfied: pygments>=2.4.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.15.1)
# Requirement already satisfied: decorator in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.1.1)
# Requirement already satisfied: stack-data in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.6.2)
# Requirement already satisfied: backcall in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.0)
# Requirement already satisfied: entrypoints in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from jupyter-client>=5.3.4->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.4)
# Collecting jupyter-server>=1.8
#   Downloading jupyter_server-2.7.0-py3-none-any.whl (375 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.1/375.1 kB 19.0 MB/s eta 0:00:00
# Collecting notebook-shim>=0.2.3
#   Downloading notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: beautifulsoup4 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.12.2)
# Collecting bleach!=5.0.0
#   Downloading bleach-6.0.0-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 9.5 MB/s eta 0:00:00
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.0.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 5.4 MB/s eta 0:00:00
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.8.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 3.9 MB/s eta 0:00:00
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: fastjsonschema in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from nbformat->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.16.3)
# Requirement already satisfied: ptyprocess in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from terminado>=0.8.3->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.7.0)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 4.8 MB/s eta 0:00:00
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: webencodings in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.5.1)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.8.3)
# Collecting jupyter-server-terminals
#   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: anyio>=3.1.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (3.6.2)
# Collecting tornado>=6.0.4
#   Downloading tornado-6.3.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.9/426.9 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.5.1)
# Collecting jupyter-client>=5.3.4
#   Downloading jupyter_client-8.3.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 5.9 MB/s eta 0:00:00
# Collecting jupyter-events>=0.6.0
#   Downloading jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Collecting overrides
#   Downloading overrides-7.3.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.3.2.post1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.2.1)
# Requirement already satisfied: pure-eval in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.3.0)
# Requirement already satisfied: pycparser in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.21)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 6.5 MB/s eta 0:00:00
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=1.11
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: arrow>=0.15.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from isoduration->jsonschema->ray[default]>=1.13.0->modin[all]) (1.2.3)
# Building wheels for collected packages: gpustat
#   Building wheel for gpustat (pyproject.toml) ... done
#   Created wheel for gpustat: filename=gpustat-1.1-py3-none-any.whl size=26280 sha256=078d013a5ff43e9df8f88a282dba64bc39f35d85f1a6e5f8e07ac9f4d2bc582d
#   Stored in directory: /home/timssh/.cache/pip/wheels/ee/d0/2c/1e02440645c2318ba03aea99993a44a9108dc8f74de0bd370b
# Successfully built gpustat
# Installing collected packages: sortedcontainers, py-spy, opencensus-context, nvidia-ml-py, ipython-genutils, colorful, zict, webcolors, virtualenv, uri-template, tornado, tinycss2, tblib, smart-open, Send2Trash, rfc3986-validator, rfc3339-validator, python-json-logger, pyasn1, pyarrow, prometheus-client, plumbum, pandocfilters, overrides, mpi4py-mpich, mistune, locket, jupyterlab-pygments, jsonpointer, jmespath, grpcio, googleapis-common-protos, fqdn, defusedxml, cloudpickle, cachetools, bleach, unidist, terminado, rsa, rpyc, ray, qtpy, pyasn1-modules, partd, jupyter-client, gpustat, botocore, argon2-cffi-bindings, s3transfer, nbclient, modin, jupyter-server-terminals, isoduration, google-auth, dask, argon2-cffi, aiohttp-cors, nbconvert, google-api-core, distributed, boto3, qtconsole, opencensus, jupyter-events, jupyter-console, jupyter-server, notebook-shim, nbclassic, notebook, jupyter, modin-spreadsheet
#   Attempting uninstall: virtualenv
#     Found existing installation: virtualenv 20.21.1
#     Uninstalling virtualenv-20.21.1:
#       Successfully uninstalled virtualenv-20.21.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 7.3.4
#     Uninstalling jupyter-client-7.3.4:
#       Successfully uninstalled jupyter-client-7.3.4
# Successfully installed Send2Trash-1.8.2 aiohttp-cors-0.7.0 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 bleach-6.0.0 boto3-1.27.0 botocore-1.30.0 cachetools-5.3.1 cloudpickle-2.2.1 colorful-0.5.5 dask-2023.6.1 defusedxml-0.7.1 distributed-2023.6.1 fqdn-1.5.1 google-api-core-2.11.1 google-auth-2.21.0 googleapis-common-protos-1.59.1 gpustat-1.1 grpcio-1.51.3 ipython-genutils-0.2.0 isoduration-20.11.0 jmespath-1.0.1 jsonpointer-2.4 jupyter-1.0.0 jupyter-client-8.3.0 jupyter-console-6.6.3 jupyter-events-0.6.3 jupyter-server-2.7.0 jupyter-server-terminals-0.4.4 jupyterlab-pygments-0.2.2 locket-1.0.0 mistune-3.0.1 modin-0.22.2 modin-spreadsheet-0.1.2 mpi4py-mpich-3.1.2 nbclassic-1.0.0 nbclient-0.8.0 nbconvert-7.6.0 notebook-6.5.4 notebook-shim-0.2.3 nvidia-ml-py-11.525.131 opencensus-0.11.2 opencensus-context-0.1.3 overrides-7.3.1 pandocfilters-1.5.0 partd-1.4.0 plumbum-1.8.2 prometheus-client-0.17.0 py-spy-0.3.14 pyarrow-12.0.1 pyasn1-0.5.0 pyasn1-modules-0.3.0 python-json-logger-2.0.7 qtconsole-5.4.3 qtpy-2.3.1 ray-2.5.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpyc-4.1.5 rsa-4.9 s3transfer-0.6.1 smart-open-6.3.0 sortedcontainers-2.4.0 tblib-2.0.0 terminado-0.17.1 tinycss2-1.2.1 tornado-6.3.2 unidist-0.3.0 uri-template-1.3.0 virtualenv-20.21.0 webcolors-1.13 zict-3.0.0
# Requirement already satisfied: gradio in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (3.28.3)
# Requirement already satisfied: fastapi in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (0.88.0)
# Requirement already satisfied: aiofiles in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (23.1.0)
# Requirement already satisfied: httpx in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (0.24.0)
# Requirement already satisfied: semantic-version in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: pyyaml in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (6.0)
# Requirement already satisfied: orjson in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (3.8.12)
# Requirement already satisfied: pydub in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: pygments>=2.12.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (2.15.1)
# Requirement already satisfied: pandas in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: matplotlib in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (3.7.1)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (0.14.1)
# Requirement already satisfied: gradio-client>=0.1.3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (0.2.0)
# Requirement already satisfied: websockets>=10.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (10.3)
# Requirement already satisfied: ffmpy in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: numpy in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (1.24.3)
# Requirement already satisfied: python-multipart in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: jinja2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: pillow in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (1.9.1)
# Requirement already satisfied: requests in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (2.29.0)
# Requirement already satisfied: typing-extensions in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (4.5.0)
# Requirement already satisfied: altair>=4.2.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (4.2.2)
# Requirement already satisfied: markupsafe in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (2.1.1)
# Requirement already satisfied: uvicorn in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (0.22.0)
# Requirement already satisfied: aiohttp in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio) (3.8.4)
# Requirement already satisfied: toolz in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: entrypoints in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from altair>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from altair>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: fsspec in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio-client>=0.1.3->gradio) (2023.4.0)
# Requirement already satisfied: packaging in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from gradio-client>=0.1.3->gradio) (20.9)
# Requirement already satisfied: tqdm>=4.42.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from huggingface-hub>=0.13.0->gradio) (4.65.0)
# Requirement already satisfied: filelock in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from huggingface-hub>=0.13.0->gradio) (3.9.0)
# Requirement already satisfied: mdurl~=0.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.0)
# Requirement already satisfied: linkify-it-py<3,>=1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from pandas->gradio) (2023.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp->gradio) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp->gradio) (2.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from aiohttp->gradio) (23.1.0)
# Requirement already satisfied: starlette==0.22.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from fastapi->gradio) (0.22.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from starlette==0.22.0->fastapi->gradio) (3.6.2)
# Requirement already satisfied: certifi in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from httpx->gradio) (2022.12.7)
# Requirement already satisfied: sniffio in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: idna in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from httpx->gradio) (2.10)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from httpx->gradio) (0.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from matplotlib->gradio) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from matplotlib->gradio) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from matplotlib->gradio) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from requests->gradio) (1.26.15)
# Requirement already satisfied: h11>=0.8 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from uvicorn->gradio) (0.14.0)
# Requirement already satisfied: click>=7.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from uvicorn->gradio) (8.1.3)
# Requirement already satisfied: six in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from cycler>=0.10->matplotlib->gradio) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Requirement already satisfied: uc-micro-py in /home/timssh/miniconda3/envs/tagging/lib/python3.10/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.2)

# %%
import torch #needed only for GPU
from PIL import Image
from io import BytesIO
import numpy as np
from diffusers import StableDiffusionLatentUpscalePipeline, StableDiffusionUpscalePipeline
import gradio as gr
import modin.pandas as pd

# load model for CPU or GPU

model_2x = "stabilityai/sd-x2-latent-upscaler"
model_4x = "stabilityai/stable-diffusion-x4-upscaler"
device = "cuda" if torch.cuda.is_available() else "cpu"
upscaler2x = StableDiffusionLatentUpscalePipeline.from_pretrained(model_2x, torch_dtype=torch.float16) if torch.cuda.is_available() else StableDiffusionLatentUpscalePipeline.from_pretrained(model_2x)
upscaler4x = StableDiffusionUpscalePipeline.from_pretrained(model_4x, torch_dtype=torch.float16, revision="fp16") if torch.cuda.is_available() else StableDiffusionUpscalePipeline.from_pretrained(model_4x)
upscaler2x = upscaler2x.to(device)
upscaler4x = upscaler4x.to(device)

#define interface 

def upscale(raw_img, model, prompt, negative_prompt, scale, steps, Seed):
    generator = torch.manual_seed(Seed)
    raw_img = Image.open(raw_img).convert("RGB")
    if model == "Upscaler 4x":
        low_res_img = raw_img.resize((128, 128))
        upscaled_image = upscaler4x(prompt=prompt, negative_prompt=negative_prompt, image=low_res_img, guidance_scale=scale, num_inference_steps=steps).images[0]
    else:
        raw_img = raw_img.resize((256, 176)) 
        upscaled_image = upscaler2x(prompt=prompt, negative_prompt=negative_prompt, image=raw_img, guidance_scale=scale, num_inference_steps=steps).images[0]
    return upscaled_image
    
#launch interface
    
# gr.Interface(fn=upscale, inputs=[
#     gr.Image(type="filepath", label='Lower Resolution Image'), 
#     gr.Radio(['Upscaler 2x','Upscaler 4x'], label="Models"),
#     gr.Textbox(label="Optional: Enter a Prompt to Guide the AI's Enhancement, this can have an Img2Img Effect"), 
#     gr.Textbox(label='Experimental: Influence What you do not want the AI to Enhance. Such as Blur, Smudges, or Pixels'), 
#     gr.Slider(1, 15, 1, step=1, label='Guidance Scale: How much the AI influences the Upscaling.'), 
#     gr.Slider(5, 50, 5, step=1, label='Number of Iterations'),
#     gr.Slider(minimum=1, maximum=999999999999999999, randomize=True, step=1)], 
#     outputs=gr.Image(type="filepath", label = 'Upscaled Image'), 
#     title='SD Upscaler', 
#     description='2x Latent Upscaler using SD 2.0 And 4x Upscaler using SD 2.1. This version runs on CPU or GPU and is currently running on a T4 GPU. For 4x Upscaling use images lower than 512x512, ideally 128x128 or smaller for 512x512 output. For 2x Upscaling use up to 512x512 images for 1024x1024 output.<br><br><b>Notice: Largest Accepted Resolution is 512x512', 
#     article = "Code Monkey: <a href=\"https://huggingface.co/Manjushri\">Manjushri</a>").launch(share=True)
# Out:
# vae/diffusion_pytorch_model.safetensors not found

# %%
import os

# %%
bad_path ='/home/timssh/ML/TAGGING/test/bad/'
os.listdir(bad_path)
# Out:
# ['b9de88cab8d2112cb7e92600fdadb730.jpg',
#  '069c4a58dc666a49b5095f366cdec20e.jpg',
#  'e7bf1cc487ccce683fe2c17436c15c2d.jpg',
#  'a266eee9b76108a115b52c4a3ade797e.jpg',
#  '9ae3811cc4c01b61f1828fa10e59b36a.jpg',
#  'd6f73460e57232ee675f5af8ff869cc7.jpg',
#  'c85f42eb925a433e66cca407eee039df.jpg',
#  '1d202ecb6781efee8d88889d81734745.jpg',
#  'ec6105c9d85302d90f2fcbb8abea6016.jpg',
#  'd426e685c59df3bff996762ba1197427.jpg',
#  '0fb7ddbd49b10ffb2555d1663df95051.jpg',
#  'ce1ce86850cdc417a81fee946e445972.jpg',
#  '33ac8b5ec173216b02780f4de877549f.jpg',
#  'dd9d1c99f4cec57f7823b3094522ce69.jpg']

# %%
for path in os.listdir(bad_path):
    raw_img = os.path.join(bad_path, path)
    upscale(raw_img, "Upscaler 2x", '', '', 5, 10, 34566).save(os.path.join('flagged', path))

# %%
raw_img = os.path.join(bad_path, path)
img = Image.open(raw_img).convert("RGB")
# low_res_img = raw_img.resize((128, 128))

# %%
img.size[0], img.size[1]
# Out:
# (352, 198)

# %%
int(str(img.size[0] / 32).split(".")[0])
# Out:
# 11
