# %%
from PIL import Image
from ultralytics import YOLO
import os

model = YOLO("/home/timssh/ML/TAGGING/CLS/instance/best.pt")

# %%
for image in os.listdir("test"):
    img = Image.open("test/" + image)
    results = model(img)
    for r in results:
        im_array = r.plot()  # plot a BGR numpy array of predictions
        im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
        im.save(f'test_out/{image}.jpg')  # save image
# Out:
# 0: 352x640 1 girl, 1 man, 7.3ms
# Speed: 3.1ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 384x640 1 girl, 1 man, 62.6ms
# Speed: 0.9ms preprocess, 62.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 girl, 3 mans, 7.2ms
# Speed: 0.8ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 girl, 1 man, 7.2ms
# Speed: 0.8ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 girl, 2 mans, 62.3ms
# Speed: 0.9ms preprocess, 62.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 girl, 61.8ms
# Speed: 0.9ms preprocess, 61.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 girl, 1 man, 7.4ms
# Speed: 0.8ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 girl, 1 man, 7.2ms
# ...

# %%
Image.fromarray(results[0].plot())
# Out:
# <PIL.Image.Image image mode=RGB size=741x384>

# %%
results[0].pil
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 results[0].pil
#
# File ~/miniconda3/envs/tagging/lib/python3.10/site-packages/ultralytics/utils/__init__.py:136, in SimpleClass.__getattr__(self, attr)
#     134 """Custom attribute access error message with helpful information."""
#     135 name = self.__class__.__name__
# --> 136 raise AttributeError(f"'{name}' object has no attribute '{attr}'. See valid attributes below.\n{self.__doc__}")
#
# AttributeError: 'Results' object has no attribute 'pil'. See valid attributes below.
#
#     A class for storing and manipulating inference results.
#
#     Args:
#         orig_img (numpy.ndarray): The original image as a numpy array.
#         path (str): The path to the image file.
#         names (dict): A dictionary of class names.
# ...
